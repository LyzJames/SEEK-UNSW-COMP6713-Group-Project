# %%
from common import MissionType
from mistral_config import MistralConfig
from mistral_data import MistralData
from mistral_model import MistralModel

wa_config = MistralConfig(MissionType.WA)
wa_data = MistralData(MissionType.WA)

wa_model = MistralModel(wa_config, wa_data)
# Out:
# 2025-04-27 23:39:56 - INFO - Creating jsonl for Index(['id', 'job_ad', 'y_true'], dtype='object') rows
# Creating jsonl: 100%|██████████| 99/99 [00:00<00:00, 49421.10it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 2025-04-27 23:39:57 - INFO - Creating jsonl for Index(['id', 'job_ad', 'y_true'], dtype='object') rows
# Creating jsonl: 100%|██████████| 99/99 [00:00<00:00, 51005.54it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 2025-04-27 23:39:58 - INFO - We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# ...
# Map:   0%|          | 0/99 [00:00<?, ? examples/s]
# 2025-04-27 23:40:07 - INFO - Model and tokenizer loaded successfully.

# %%
wa_model.train()
# Out:
# ...
# Truncating train dataset:   0%|          | 0/99 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mingyuancui (mingyuancui-unsw) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>d:\UNSW\COMP6713-SEEK-Project\CODE\fine_tuning_evaluation\wandb\run-20250427_234114-7nahtn2k</code>
# ...

# %% [markdown]
# #### The other tasks, being too time-consuming, will be trained on Colab, following the same pattern

# %%
se_config = MistralConfig(MissionType.SE)
se_data = MistralData(MissionType.SE)

se_model = MistralModel(se_config, se_data)
se_model.train()

# %%
sa_config = MistralConfig(MissionType.SA)
sa_data = MistralData(MissionType.SA)

sa_model = MistralModel(sa_config, sa_data)
sa_model.train()
