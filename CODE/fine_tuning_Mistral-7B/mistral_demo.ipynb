# %%
# -*- coding: utf-8 -*-
import numpy as np
import torch

print(f"torch version: {torch.__version__}")
print(f"torch cuda version: {torch.version.cuda}")
device = torch.device(
    torch.cuda.current_device() if torch.cuda.is_available() else "cpu"
)
print(f"torch device: {device}")
print(
    f"device name: {torch.cuda.get_device_name(device) if torch.cuda.is_available() else 'cpu'}"
)

import random

random.seed(42)
np.random.seed(42)
# Out:
# torch version: 2.6.0+cu126
# torch cuda version: 12.6
# torch device: cuda:0
# device name: NVIDIA GeForce RTX 4090 Laptop GPU
# MISC_DATA_PATH: ..\..\MISC
# JOB_DATA_PATH: ..\..\MISC\job_data_files

# %%
from demo import MistralDemo

demo = MistralDemo(device)
demo.launch(share=True, debug=True, show_error=True)
# Out:
# 2025-04-26 23:35:46 - INFO - HTTP Request: GET http://127.0.0.1:7860/gradio_api/startup-events "HTTP/1.1 200 OK"
# * Running on local URL:  http://127.0.0.1:7860
# 2025-04-26 23:35:46 - INFO - HTTP Request: HEAD http://127.0.0.1:7860/ "HTTP/1.1 200 OK"
# 2025-04-26 23:35:47 - INFO - HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 2025-04-26 23:35:47 - INFO - HTTP Request: GET https://api.gradio.app/v3/tunnel-request "HTTP/1.1 200 OK"
# * Running on public URL: https://9cdaea8128663d8557.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2025-04-26 23:35:49 - INFO - HTTP Request: HEAD https://9cdaea8128663d8557.gradio.live "HTTP/1.1 200 OK"
# <div><iframe src="https://9cdaea8128663d8557.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 2025-04-26 23:37:00 - INFO - We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://9cdaea8128663d8557.gradio.live
